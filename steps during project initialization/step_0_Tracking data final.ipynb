# %%
muln,tsla,nvda,aapl,mara,meta,TATASTEEL.NSE
# stock_name_list = ['TATASTEEL.NSE','TCS.NSE','TATAMOTORS.NSE','TATAPOWER.NSE','TATACHEM.NSE','TATACONSUM.NSE','TITAN.NSE',
#                    'TATAELXSI.NSE','MSFT','RELIANCE.NSE','TSLA','ADANIENT.NSE','ADANIGREEN.NSE','ADANIPORTS.NSE',
#                    'ADANIPOWER.NSE','ATGL.NSE','AMBUJACEM.NSE','ADANITRANS.NSE','RIOT','AI','AMZN','JNJ',
#                   'GM','APE','SCHW','PYPL','GOOGL','WMT','XOM','T','ORCL','CVX','ACN'] track done DONE
# stock_name_list = ['ALL','MO','LNT','AEE','AAL','AMT','AWK','AMP','AME','AMGN','APH','ADI'] track done DONE
# ['CHRW','CDNS','CZR','CPT','CPT','COF','CAH','KMX','CCL','CARR','CTLT','CAT','CBOE','CBRE','CDW','CE','COR','CNP','CDAY','CF','CNC','CB','CMG','CVX']
# track done DONE
# stock_name_list = ['C','CFG','CLX','CME','CMS','KO','CTSH','CL','CMCSA','CMA','CAG','COP'] 
#track done Done
# stock_name_list = ['ES','EXC','EXPE','EXPD','EXR','XOM','FFIV','FDS','FICO','FAST','FRT','FDX','FITB','FSLR',
#                   'FE','FIS','FI','FLT','FMC','F','FTNT','FTV','FOXA','FOX','BEN','FCX','GRMN','IT','GEHC'] 
#track done DONE
# stock_name_list = ['MTB','MRO','MPC','MKTX','MAR','MMC','MLM','MAS','MA','MTCH','MKC','MCD','MCK','MDT','MRK','META',
#                    'MET','MTD','MGM','MCHP','MU','MAA','MRNA','MHK','MOH','TAP','MDLZ','MPWR','MNST','MCO','MS','MOS','MSI'] # for terminal 1(working)
# track done DONE
# stock_name_list= ['ED','STZ','CEG','COO','CPRT','GLW','CTVA','CSGP','COST','CTRA','CCI','CSX','CMI']
#track done DONE
# stock_name_list=['CVS','DHI','DHR','DRI','DVA','DE','DAL','XRAY','DVN','DXCM','FANG','DLR','DFS','DIS','DG','DLTR']
#track done DONE
# stock_name_list=['D','DPZ','DOV','DOW','DTE','DUK','DD','DXC','EMN','ETN','EBAY','ECL','EIX','EW','EA','ELV',
#                 'LLY','EMR','ENPH','ETR','EOG','EPAM','EQT','EFX','EQIX','EQR','ESS','EL','ETSY','EG','EVRG']
#track done DONE
# stock_name_list= ['HAL']
# track done DONE
# stock_name_list = ['MSCI','NDAQ','NTAP','NWL','NEM','NWSA','NWS','NEE','NKE','NI','NDSN','NSC','NTRS','NOC','NCLH','NRG','NUE',
#                    'NVR']  
#track done DONE
# stock_name_list =['NXPI','ORLY','OXY','ODFL','OMC','ON','OKE','ORCL','OGN','OTIS','PCAR','PKG','PANW','PARA','PH',
#                   'PAYX','PAYC','PNR','PEP','PFE']    # for 4rd terminal  (working)
#TRACK DONE
# stock_name_list = ['PCG','PM','PSX','PNW','PXD','PNC','POOL','PPG','PPL','PFG','PG','PGR','PLD','PRU','PEG','PTC','PSA','PHM',
#                   'QRVO','PWR','QCOM','DGX','RL','RJF','RTX','O'] # for 5th terminal   (working)*
#Track done Done
# stock_name_list = ['REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK','ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 
#                    'STX', 'SEE','SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT'] # for 2nd terminal(working)
#track done DONE 
# stock_name_list = ['STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL', 'TDY', 'TFX', 'TER',
#                    'TXN', 'TXT', 'COO', 'HIG', 'HSY', 'MOS', 'TRV', 'DIS', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRMB'] # for 3rd terminal (working)
#track done Done
# stock_name_list = ['ULTA', 'UAA', 'UA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 
#                    'VFC', 'VIAC', 'VTRS', 'V', 'VNO', 'VMC', 'WRB']  # for 6th terminal (working)
#track done DONE
# stock_name_list = ['GWW', 'WAB', 'WBA','WMT', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WU', 'WRK', 'WY',
#                    'WHR', 'WMB', 'WLTW', 'WYNN', 'XEL', 'XLNX', 'XYL', 'YUM', 'ZBRA', 'ZBH','ZION'] # for 7th terminal (working)
#track done Done

# %%
stock_name_list = ['TATASTEEL.NSE','TCS.NSE','TATAMOTORS.NSE','TATAPOWER.NSE','TATACHEM.NSE','TATACONSUM.NSE','TITAN.NSE',
                  'TATAELXSI.NSE','MSFT','RELIANCE.NSE','TSLA','ADANIENT.NSE','ADANIGREEN.NSE','ADANIPORTS.NSE',
                  'ADANIPOWER.NSE','ATGL.NSE','AMBUJACEM.NSE','ADANITRANS.NSE','RIOT','AI','AMZN','JNJ',
                  'GM','APE','SCHW','PYPL','GOOGL','WMT','XOM','T','ORCL','CVX','ACN','ALL','MO','LNT','AEE',
                   'AAL','AMT','AWK','AMP','AME','AMGN','APH','ADI','CHRW','CDNS','CZR','CPT','CPT','COF','CAH',
                   'KMX','CCL','CARR','CTLT','CAT','CBOE','CBRE','CDW','CE','COR','CNP','CDAY','CF','CNC','CB','CMG','CVX',
                  'C','CFG','CLX','CME','CMS','KO','CTSH','CL','CMCSA','CMA','CAG','COP','ES','EXC','EXPE','EXPD','EXR','XOM',
                   'FFIV','FDS','FICO','FAST','FRT','FDX','FITB','FSLR','FE','FIS','FI','FLT','FMC','F','FTNT','FTV','FOXA',
                   'FOX','BEN','FCX','GRMN','IT','GEHC','MTB','MRO','MPC','MKTX','MAR','MMC','MLM','MAS','MA','MTCH','MKC','MCD',
                   'MCK','MDT','MRK','META','MET','MTD','MGM','MCHP','MU','MAA','MRNA','MHK','MOH','TAP','MDLZ','MPWR','MNST',
                   'MCO','MS','MOS','MSI','ED','STZ','CEG','COO','CPRT','GLW','CTVA','CSGP','COST','CTRA','CCI','CSX','CMI',
                  'CVS','DHI','DHR','DRI','DVA','DE','DAL','XRAY','DVN','DXCM','FANG','DLR','DFS','DIS','DG','DLTR',
                  'D','DPZ','DOV','DOW','DTE','DUK','DD','DXC','EMN','ETN','EBAY','ECL','EIX','EW','EA','ELV',
                   'LLY','EMR','ENPH','ETR','EOG','EPAM','EQT','EFX','EQIX','EQR','ESS','EL','ETSY','EG','EVRG','HAL',
                   'MSCI','NDAQ','NTAP','NWL','NEM','NWSA','NWS','NEE','NKE','NI','NDSN','NSC','NTRS','NOC','NCLH','NRG','NUE',
                   'NVR','NXPI','ORLY','OXY','ODFL','OMC','ON','OKE','ORCL','OGN','OTIS','PCAR','PKG','PANW','PARA','PH',
                  'PAYX','PAYC','PNR','PEP','PFE','PCG','PM','PSX','PNW','PXD','PNC','POOL','PPG','PPL','PFG','PG','PGR',
                   'PLD','PRU','PEG','PTC','PSA','PHM','QRVO','PWR','QCOM','DGX','RL','RJF','RTX','O','REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK','ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 
                   'STX', 'SEE','SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT','STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL', 'TDY', 'TFX', 'TER',
                   'TXN', 'TXT', 'COO', 'HIG', 'HSY', 'MOS', 'TRV', 'DIS', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRMB','ULTA',
                   'UAA', 'UA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 
                   'VFC', 'VIAC', 'VTRS', 'V', 'VNO', 'VMC', 'WRB','GWW', 'WAB', 'WBA','WMT', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WU', 'WRK', 'WY',
                   'WHR', 'WMB', 'WLTW', 'WYNN', 'XEL', 'XLNX', 'XYL', 'YUM', 'ZBRA', 'ZBH','ZION']

# %%
print(len(stock_name_list))
# Out:
# 372

# %%
print(len(stock_names))
# Out:
# 364

# %%
import pymongo
from datetime import date, timedelta, datetime
stock_name_list = ['TATASTEEL.NSE','TCS.NSE','TATAMOTORS.NSE','TATAPOWER.NSE','TATACHEM.NSE','TATACONSUM.NSE','TITAN.NSE',
                  'TATAELXSI.NSE','MSFT','RELIANCE.NSE','TSLA','ADANIENT.NSE','ADANIGREEN.NSE','ADANIPORTS.NSE',
                  'ADANIPOWER.NSE','ATGL.NSE','AMBUJACEM.NSE','ADANITRANS.NSE','RIOT','AI','AMZN','JNJ',
                  'GM','APE','SCHW','PYPL','GOOGL','WMT','XOM','T','ORCL','CVX','ACN','ALL','MO','LNT','AEE',
                   'AAL','AMT','AWK','AMP','AME','AMGN','APH','ADI','CHRW','CDNS','CZR','CPT','CPT','COF','CAH',
                   'KMX','CCL','CARR','CTLT','CAT','CBOE','CBRE','CDW','CE','COR','CNP','CDAY','CF','CNC','CB','CMG','CVX',
                  'C','CFG','CLX','CME','CMS','KO','CTSH','CL','CMCSA','CMA','CAG','COP','ES','EXC','EXPE','EXPD','EXR','XOM',
                   'FFIV','FDS','FICO','FAST','FRT','FDX','FITB','FSLR','FE','FIS','FI','FLT','FMC','F','FTNT','FTV','FOXA',
                   'FOX','BEN','FCX','GRMN','IT','GEHC','MTB','MRO','MPC','MKTX','MAR','MMC','MLM','MAS','MA','MTCH','MKC','MCD',
                   'MCK','MDT','MRK','META','MET','MTD','MGM','MCHP','MU','MAA','MRNA','MHK','MOH','TAP','MDLZ','MPWR','MNST',
                   'MCO','MS','MOS','MSI','ED','STZ','CEG','COO','CPRT','GLW','CTVA','CSGP','COST','CTRA','CCI','CSX','CMI',
                  'CVS','DHI','DHR','DRI','DVA','DE','DAL','XRAY','DVN','DXCM','FANG','DLR','DFS','DIS','DG','DLTR',
                  'D','DPZ','DOV','DOW','DTE','DUK','DD','DXC','EMN','ETN','EBAY','ECL','EIX','EW','EA','ELV',
                   'LLY','EMR','ENPH','ETR','EOG','EPAM','EQT','EFX','EQIX','EQR','ESS','EL','ETSY','EG','EVRG','HAL',
                   'MSCI','NDAQ','NTAP','NWL','NEM','NWSA','NWS','NEE','NKE','NI','NDSN','NSC','NTRS','NOC','NCLH','NRG','NUE',
                   'NVR','NXPI','ORLY','OXY','ODFL','OMC','ON','OKE','ORCL','OGN','OTIS','PCAR','PKG','PANW','PARA','PH',
                  'PAYX','PAYC','PNR','PEP','PFE','PCG','PM','PSX','PNW','PXD','PNC','POOL','PPG','PPL','PFG','PG','PGR',
                   'PLD','PRU','PEG','PTC','PSA','PHM','QRVO','PWR','QCOM','DGX','RL','RJF','RTX','O','REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK','ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 
                   'STX', 'SEE','SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT','STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL', 'TDY', 'TFX', 'TER',
                   'TXN', 'TXT', 'COO', 'HIG', 'HSY', 'MOS', 'TRV', 'DIS', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRMB','ULTA',
                   'UAA', 'UA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 
                   'VFC', 'VIAC', 'VTRS', 'V', 'VNO', 'VMC', 'WRB','GWW', 'WAB', 'WBA','WMT', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WU', 'WRK', 'WY',
                   'WHR', 'WMB', 'WLTW', 'WYNN', 'XEL', 'XLNX', 'XYL', 'YUM', 'ZBRA', 'ZBH','ZION']
stock_name_list = set(stock_name_list)
print(len(stock_name_list))
status = 'pending'
if __name__ == "__main__":
    for stock_name in stock_name_list:
        client = pymongo.MongoClient("mongodb://localhost:27017")
        db = client['Final_Year_Project']
        collection = db[f'tracking_data']
        ##################################
        first_date = '2017/1/1' 
        second_date = '2016/1/1' 
#         first_date = '2023/7/31' # it will scrape before selected date     # 2023/1/1
#         second_date = '2023/1/1'                                           # 2022/1/1
        first_date=datetime.strptime(first_date,'%Y/%m/%d')
        second_date=datetime.strptime(second_date,'%Y/%m/%d')
        differ_date = abs((second_date - first_date).days)
        days_sample = []
        for i in range(differ_date+1):
            if first_date > second_date:
                days_in_between = first_date - timedelta(days=i)
            else :
                days_in_between = second_date - timedelta(days=i)
        #     print(days_in_between)
            days_sample.append(days_in_between)
    #         days_sample_str = []
    #         for i in days_sample:
    #             days_str = str(i)
    #             days_sample_str.append(days_str)
        sorted_numbers = sorted(days_sample, reverse=True) # in decending order
        total = len(days_sample)
        for i in range(total):
            if total == 1:
                break
            start_date = days_sample[0]
    #         print('start_date:',start_date)
            end_date = days_sample[1]
    #         print('end_date:',end_date)
            days_sample.pop(0)
    #         print(total)
            total = total - 1
            dictionary = {'start_date': start_date,'end_date':end_date,'stock_name':stock_name,'status':status,'next_api':''}
            collection.insert_one(dictionary)
        print(f'{stock_name} is all set')
    print(f'All done go and check to your database names [tracking_data]')
# Out:
# 364
# ACN is all set
# CPRT is all set
# EXC is all set
# CAG is all set
# PHM is all set
# AMZN is all set
# EPAM is all set
# DLR is all set
# UAL is all set
# PPL is all set
# OMC is all set
# ODFL is all set
# PNR is all set
# VTR is all set
# TATASTEEL.NSE is all set
# EA is all set
# MSI is all set
# EOG is all set
# PSA is all set
# QCOM is all set
# TRV is all set
# WRK is all set
# ROL is all set
# SHW is all set
# FIS is all set
# ADANIPORTS.NSE is all set
# TPR is all set
# TFX is all set
# REGN is all set
# DVN is all set
# PAYC is all set
# EQIX is all set
# DLTR is all set
# HIG is all set
# WST is all set
# ROST is all set
# STE is all set
# CFG is all set
# AI is all set
# MRO is all set
# ELV is all set
# TMO is all set
# ECL is all set
# SWK is all set
# CF is all set
# SLB is all set
# EL is all set
# CMCSA is all set
# STX is all set
# DRI is all set
# CBRE is all set
# META is all set
# ULTA is all set
# STT is all set
# ENPH is all set
# FAST is all set
# ...

# %%
print(stock_name_list)
# Out:
# {'ACN', 'CPRT', 'EXC', 'CAG', 'PHM', 'AMZN', 'EPAM', 'DLR', 'UAL', 'PPL', 'OMC', 'ODFL', 'PNR', 'VTR', 'TATASTEEL.NSE', 'EA', 'MSI', 'EOG', 'PSA', 'QCOM', 'TRV', 'WRK', 'ROL', 'SHW', 'FIS', 'ADANIPORTS.NSE', 'TPR', 'TFX', 'REGN', 'DVN', 'PAYC', 'EQIX', 'DLTR', 'HIG', 'WST', 'ROST', 'STE', 'CFG', 'AI', 'MRO', 'ELV', 'TMO', 'ECL', 'SWK', 'CF', 'SLB', 'EL', 'CMCSA', 'STX', 'DRI', 'CBRE', 'META', 'ULTA', 'STT', 'ENPH', 'FAST', 'VTRS', 'FRT', 'FITB', 'VRSN', 'NI', 'CCL', 'MDLZ', 'UPS', 'AMGN', 'UNP', 'MA', 'PTC', 'VMC', 'DUK', 'AMP', 'CVX', 'COO', 'FOX', 'WELL', 'CZR', 'NEM', 'COF', 'VRSK', 'TATAPOWER.NSE', 'CDAY', 'OGN', 'RL', 'CME', 'RELIANCE.NSE', 'PEP', 'ZION', 'CRM', 'NSC', 'RCL', 'EXR', 'DOV', 'MKTX', 'WY', 'PCG', 'ETSY', 'MAA', 'TMUS', 'ALL', 'ROP', 'TATACHEM.NSE', 'DFS', 'LNT', 'MTCH', 'FFIV', 'GM', 'ORCL', 'ORLY', 'CTRA', 'CMG', 'STZ', 'FOXA', 'SBAC', 'TATAELXSI.NSE', 'PM', 'QRVO', 'SNA', 'CHRW', 'T', 'EG', 'UA', 'RTX', 'TXT', 'VIAC', 'COR', 'PWR', 'CNP', 'SWKS', 'CDNS', 'GEHC', 
# ...

# %%
set_ = ['ACN', 'CPRT', 'EXC', 'CAG', 'PHM', 'AMZN',
        'EPAM', 'DLR', 'UAL', 'PPL', 'OMC', 'ODFL',
        'PNR', 'VTR', 'TATASTEEL.NSE', 'EA', 'MSI', 
        'EOG', 'PSA', 'QCOM', 'TRV', 'WRK', 'ROL', 'SHW', 
        'FIS', 'ADANIPORTS.NSE', 'TPR', 'TFX', 'REGN', 
        'DVN', 'PAYC', 'EQIX', 'DLTR', 'HIG', 'WST', 'ROST',
        'STE', 'CFG', 'AI', 'MRO', 'ELV', 'TMO', 'ECL', 'SWK',termianl 1
        'CF', 'SLB', 'EL', 'CMCSA', 'STX', 'DRI', 'CBRE', 'META', 'ULTA', 'STT', 'ENPH',
        'FAST', 'VTRS', 'FRT', 'FITB', 'VRSN', 'NI', 'CCL', 'MDLZ', 'UPS', 'AMGN', 'UNP', 
        'MA', 'PTC', 'VMC', 'DUK', 'AMP', 'CVX', 'COO', 'FOX', 'WELL', 'CZR', 'NEM', 'COF',
        'VRSK', 'TATAPOWER.NSE', 'CDAY', 'OGN', 'RL', 'CME', 'RELIANCE.NSE', 'PEP', 'ZION', 
        'CRM', 'NSC', 'RCL', 'EXR', 'DOV', 'MKTX', 'WY', 'PCG', 'ETSY', 'MAA', 'TMUS', 'ALL', terminal 2
        'ROP', 'TATACHEM.NSE', 'DFS', 'LNT', 'MTCH', 'FFIV', 'GM', 'ORCL', 'ORLY', 'CTRA', 
        'CMG', 'STZ', 'FOXA', 'SBAC', 'TATAELXSI.NSE', 'PM', 'QRVO', 'SNA', 'CHRW', 'T', 
        'EG', 'UA', 'RTX', 'TXT', 'VIAC', 'COR', 'PWR', 'CNP', 'SWKS', 'CDNS', 'GEHC', 'MHK', terminal 3
        'WMB', 'CARR', 'MRK', 'MAR', 'HAL', 'PG', 'EW', 'TRMB', 'CLX', 'WYNN', 'SPGI', 'YUM', 
        'ADANIENT.NSE', 'POOL', 'VRTX', 'KMX', 'DOW', 'MS', 'TGT', 'MGM', 'TDY', 'SYF', 'O', 'TSCO', 
        'ON', 'WLTW', 'EQR', 'OTIS', 'MNST', 'WEC', 'OXY', 'TAP', 'NOC', 'CMI', 'PARA', 'ADANIPOWER.NSE', terminsal 4
        'GRMN', 'MSFT', 'NCLH', 'CAH', 'RSG', 'APE', 'TSLA', 'NVR', 'MCK', 'NOW', 'PSX', 'PRU', 'FDX', 'FLT', 
        'PKG', 'SYK', 'EMN', 'SPG', 'DD', 'REG', 'RIOT', 'PEG', 'CBOE', 'NXPI', 'MPC', 'LLY', 'FSLR', 'KO', 
        'CVS', 'EIX', 'C', 'XLNX', 'GLW', 'UHS', 'NUE', 'BEN', 'ZBRA', 'PGR', 'FMC', 'SCHW', 'CB', 'HSY', 'RHI',terminal 5
        'MPWR', 'SNPS', 'PNW', 'NTRS', 'ETR', 'EXPE', 'ADANIGREEN.NSE', 'CSGP', 'DGX', 'TATAMOTORS.NSE', 'FE', 
        'EFX', 'CTVA', 'CSX', 'RJF', 'JNJ', 'WM', 'TITAN.NSE', 'AME', 'NDSN', 'ED', 'TATACONSUM.NSE', 'NTAP', 
        'COST', 'XRAY', 'WAT', 'AMT', 'SIVB', 'MAS', 'CL', 'DIS', 'MCO', 'APH', 'MO', 'ATGL.NSE', 'LUV', 'PANW',
        'NWL', 'SO', 'MDT', 'TCS.NSE', 'VNO', 'AEE', 'DHR', 'PAYX', 'D', 'FICO', 'AWK', 'FANG', 'IT', 'MCD', 
        'MLM', 'CEG', 'AAL', 'CDW', 'MOS', 'TROW', 'PNC', 'MSCI', 'PFG', 'PYPL', 'VLO', 'WU', 'PCAR', 'ADANITRANS.NSE', 
        'CPT', 'NWS', 'DXC', 'PFE', 'TJX', 'SYY', 'WMT', 'FDS', 'DHI', 'ETN', 'EBAY', 'NRG', 'CAT', 'WRB', 'RF', 
        'DAL', 'WDC', 'URI', 'WHR', 'OKE', 'UAA', 'TEL', 'PXD', 'MU', 'NEE', 'PH', 'ROK', 'EVRG', 'CCI', 'XYL',
        'UNH', 'FI', 'TXN', 'NKE', 'VZ', 'CMA', 'CNC', 'DXCM', 'TT', 'PLD', 'MMC', 'EXPD', 'MTD', 'FTV', 'WFC',
        'AMBUJACEM.NSE', 'NWSA', 'SBUX', 'V', 'DPZ', 'MOH', 'CTSH', 'MET', 'WAB', 'DG', 'DVA', 'VFC', 'MCHP', 'XEL',
        'ZBH', 'COP', 'NDAQ', 'MRNA', 'SRE', 'DE', 'GOOGL', 'TER', 'ES', 'FTNT', 'TDG', 'RMD', 'EQT', 'ADI', 'CE', 
        'XOM', 'GWW', 'WBA', 'TTWO', 'PPG', 'FCX', 'ESS', 'DTE', 'F', 'EMR', 'SEE', 'CTLT', 'MTB', 'MKC', 'CMS']
