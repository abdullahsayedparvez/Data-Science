# %%
import pandas as pd
import re

# %%
bike = pd.read_csv('bike_data.csv')

# %%
bike
# Out:
#        Unnamed: 0                                       Name     Price  \
# 0               0    TVS Star City Plus Dual Tone 110cc 2018    35,000
# 1               1           Royal Enfield Classic 350cc 2017  1,19,900
# 2               2                  Triumph Daytona 675R 2013  6,00,000
# 3               3                  TVS Apache RTR 180cc 2017    65,000
# 4               4  Yamaha FZ S V 2.0 150cc-Ltd. Edition 2018    80,000
# ...           ...                                        ...       ...
# 34495       34495                Hero Passion Pro 100cc 2017    39,000
# 34496       34496                  TVS Apache RTR 180cc 2012    30,000
# 34497       34497              Bajaj Avenger Street 220 2015    60,000
# 34498       34498             Hero Super Splendor 125cc 2005    15,600
# 34499       34499                    Bajaj Pulsar 150cc 2008    22,000
#
#         Location    Running        Owner
# 0      Ahmedabad  17,654 Km  First Owner
# ...

# %%
bike['Year_bike'] = bike['Name'].str.extract('(\d\d\d\d)',expand=True)
bike['Year_bike']
# Out:
# 0        2018
# 1        2017
# 2        2013
# 3        2017
# 4        2018
#          ...
# 34495    2017
# 34496    2012
# 34497    2015
# 34498    2005
# 34499    2008
# Name: Year_bike, Length: 34500, dtype: object

# %%
bike['Power_bike'] = bike['Name'].str.extract('(\d\d\d) , cc+',expand=True)
bike['Power_bike']

# %%
bike['name_bike'] = bike['Name'].str.extract('([A-Z]\w{0,})',expand=True)
bike['name_bike']
# Out:
# 0            TVS
# 1          Royal
# 2        Triumph
# 3            TVS
# 4         Yamaha
#           ...
# 34495       Hero
# 34496        TVS
# 34497      Bajaj
# 34498       Hero
# 34499      Bajaj
# Name: name_bike, Length: 34500, dtype: object

# %%
bike
# Out:
#        Unnamed: 0                                       Name     Price  \
# 0               0    TVS Star City Plus Dual Tone 110cc 2018    35,000
# 1               1           Royal Enfield Classic 350cc 2017  1,19,900
# 2               2                  Triumph Daytona 675R 2013  6,00,000
# 3               3                  TVS Apache RTR 180cc 2017    65,000
# 4               4  Yamaha FZ S V 2.0 150cc-Ltd. Edition 2018    80,000
# ...           ...                                        ...       ...
# 34495       34495                Hero Passion Pro 100cc 2017    39,000
# 34496       34496                  TVS Apache RTR 180cc 2012    30,000
# 34497       34497              Bajaj Avenger Street 220 2015    60,000
# 34498       34498             Hero Super Splendor 125cc 2005    15,600
# 34499       34499                    Bajaj Pulsar 150cc 2008    22,000
#
#         Location    Running        Owner  Year Year_bike Power_bike name_bike
# ...

# %%
def remove_space(column_name) :       # here we use strip functio to remove empty space from a string
    return column_name.strip()

# %%
def get_year(column_name_y):
    return column_name_y[-4:]

# %%
def get_cc(column_name_cc):
    return column_name_cc[-5:-7]

# %%
bike['Year'] = bike['Name'].apply(get_year)

# %%
df  = pd.DataFrame(people_info)

# %%
df['Year'] = df['bike_name'].apply(get_year)

# %%
df
# Out:
#                                  bike_name  Year
# 0  TVS Star City Plus Dual Tone 110cc 2018  2018

# %%
def remove_space(column_name) :       # here we use strip functio to remove empty space from a string
    return column_name.strip()

# %%
bike['Name'] = bike['Name'].apply(remove_space)

# %%
bike
# Out:
#        Unnamed: 0                                       Name     Price  \
# 0               0    TVS Star City Plus Dual Tone 110cc 2018    35,000
# 1               1           Royal Enfield Classic 350cc 2017  1,19,900
# 2               2                  Triumph Daytona 675R 2013  6,00,000
# 3               3                  TVS Apache RTR 180cc 2017    65,000
# 4               4  Yamaha FZ S V 2.0 150cc-Ltd. Edition 2018    80,000
# ...           ...                                        ...       ...
# 34495       34495                Hero Passion Pro 100cc 2017    39,000
# 34496       34496                  TVS Apache RTR 180cc 2012    30,000
# 34497       34497              Bajaj Avenger Street 220 2015    60,000
# 34498       34498             Hero Super Splendor 125cc 2005    15,600
# 34499       34499                    Bajaj Pulsar 150cc 2008    22,000
#
#         Location    Running        Owner  Year
# 0      Ahmedabad  17,654 Km  First Owner  2018
# ...

# %%
bike['Year'] = bike['Name'].str.extract('(?:cc)([2-9]{4})')

# %%
bike['Year'] = bike['Name'].str.extract('([2000-2020]+)' + 'cc')(?:cc)
